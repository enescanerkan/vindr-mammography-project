# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bf1647b42bbd> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     143   mountpoint = _os.path.expanduser(mountpoint)
#     144   # If we've already mounted drive at the specified mountpoint, exit now.
# ...

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !unzip /content/drive/MyDrive/dataset.zip -d ./data
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: ./data/dataset/images/train/f13af0df8b6fdeecca7e36affeb56988.png
#   inflating: ./data/dataset/images/train/f17d87b660e35d32339d60cd3fb556b0.png
#   inflating: ./data/dataset/images/train/f1b0fbd4eebff392ed4b9886034c29ca.png
#   inflating: ./data/dataset/images/train/f1b0fbd4eebff392ed4b9886034c29ca_aug_flip_horizontal.png
#   inflating: ./data/dataset/images/train/f1bfdcca5002d093e4b07e0099e252ec.png
#   inflating: ./data/dataset/images/train/f1f79501410a98782c0a03b48e66df83.png
#   inflating: ./data/dataset/images/train/f2504628e2a4c5e04bb39655b4776f57.png
#   inflating: ./data/dataset/images/train/f27721b219f110a419193176e5e53151.png
#   inflating: ./data/dataset/images/train/f27721b219f110a419193176e5e53151_aug_flip_both.png
#   inflating: ./data/dataset/images/train/f27721b219f110a419193176e5e53151_aug_flip_horizontal.png
# ...

# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.47 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
# !yolo detect train \
    data=/content/drive/MyDrive/config.yaml \
    model=/content/drive/MyDrive/last.pt \
    epochs=20 \
    imgsz=640 \
    workers=8 \
    batch=8 \
    device=0 \
    name=trained_data
# Out:
# Ultralytics 8.3.47 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
